# %%
from core.client import APIClient

# %%
client = APIClient(base_url="http://localhost:8000")

# %%
client.login(
    username="admin.app@example.com",
    password="secretpassword"
)
# Out:
# {'message': 'Logged in'}

# %%
print(client.me())
# Out:
# {'user': 'admin.app@example.com'}

# %%
print(client.get_low_stock(threshold=10))
# Out:
# {'items': []}

# %%
print(client.search_products(query="keyboard"))
# Out:
# {'products': [{'product_id': 49, 'name': 'Mechanical Keyboard XL', 'description': 'High-quality mechanical keyboard xl for computers applications. Designed for durability, performance, and everyday use.', 'sku': 'MEC-FC5091', 'category_id': 2, 'unit_price': 2458.63, 'created_at': '2026-04-15T14:06:10'}]}

# %%
client.register_sale(
    product_id=1,
    warehouse_id=1,
    quantity=2
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 client.register_sale(
#       2     product_id=1,
#       3     warehouse_id=1,
#       4     quantity=2
#       5 )
#
# File c:\Users\fabia\OneDrive\Documentos\Programs\Personal\PruebasXD\chatbot2\core\client.py:231, in APIClient.register_sale(self, product_id, warehouse_id, quantity)
#     216 def register_sale(
#     217     self,
#     218     product_id: int,
#     219     warehouse_id: int,
#     220     quantity: int
#     221 ) -> dict[str, Any]:
#     222     response = self.session.post(
#     223         f"{self.base_url}/operations/register-sale",
#     224         json={
#    (...)
#     228         }
#     229     )
# --> 231     response.raise_for_status()
#     232     return response.json()
#
# ...
